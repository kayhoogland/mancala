# %%
# %load_ext autoreload
# %autoreload 2
import mancala

# %%
from mancala.game.create import Board, Player
from mancala.game.play import Game

# %%
b = Board(4, "Kay", "Kirsten")
g = Game(b)

# %%
g.play_game()
# Out:
# Player Kay is up! What hole do you want to select?
#
#
#         Board:
#         [4, 4, 4, 4, 4, 4]
#         [4, 4, 4, 4, 4, 4]
#
#         Score:
#         Kay : 0
#         Kirsten : 0
#
# 0
# Player Kirsten is up! What hole do you want to select?
#
#
#         Board:
#         [4, 4, 4, 4, 4, 4]
#         [0, 5, 5, 5, 5, 4]
#
#         Score:
#         Kay : 0
#         Kirsten : 0
#
# 0
# Player Kay is up! What hole do you want to select?
#
#
#         Board:
#         [4, 5, 5, 5, 5, 0]
#         [0, 5, 5, 5, 5, 4]
#
#         Score:
#         Kay : 0
#         Kirsten : 0
#
# 1
# Player Kay is up! What hole do you want to select?
#
#
#         Board:
#         [4, 5, 5, 5, 5, 0]
#         [0, 0, 6, 6, 6, 5]
#
#         Score:
#         Kay : 1
#         Kirsten : 0
#
# 2
# Player Kirsten is up! What hole do you want to select?
#
#
#         Board:
#         [4, 5, 5, 5, 6, 1]
#         [0, 0, 0, 7, 7, 6]
#
#         Score:
#         Kay : 2
#         Kirsten : 0
#
# 0
# ...

# %%
a = [3, 4, 5]
if any(a) == 3:
    print('Bla')
